# %%
from keras.datasets import cifar10

# %%
from keras.layers import Conv2D,Flatten,Dense,MaxPool2D
from keras.models import Sequential

# %%
(X_train,X_test),(Y_train,Y_test) = cifar10.load_data()
X_train = X_train/255
Y_train = Y_train/255
print(X_train.shape)
print(X_test.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 1)

# %%
X_train = X_train.reshape(50000,32*32*3)

# %%
model = Sequential()
model.add(Dense(128,input_shape =(32*32*3,),activation ='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(3072,activation = 'sigmoid'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 128)               393344
# _________________________________________________________________
# dense_16 (Dense)             (None, 32)                4128
# _________________________________________________________________
# dense_17 (Dense)             (None, 3072)              101376
# =================================================================
# Total params: 498,848
# Trainable params: 498,848
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, X_train, epochs=3)
# Out:
# Epoch 1/3
# 50000/50000 [==============================] - 23s 454us/step - loss: 11595.3761 - acc: 0.0036
# Epoch 2/3
# 50000/50000 [==============================] - 22s 445us/step - loss: 11577.2132 - acc: 0.0044
# Epoch 3/3
# 50000/50000 [==============================] - 23s 452us/step - loss: 11572.4982 - acc: 0.0045

# %%
noise_factor = 0.4
x_train_noisy = X_train + noise_factor * np.random.normal(size=X_train.shape) 
x_test_noisy = x_test + noise_factor * np.random.normal(size=x_test.shape)

x_train_noisy = np.clip(x_train_noisy, 0.0, 1.0)
x_test_noisy = np.clip(x_test_noisy, 0.0, 1.0)

# %%
model.fit(x_train_noisy, X_train, epochs=3)
# Out:
# Epoch 1/3
# 50000/50000 [==============================] - 22s 441us/step - loss: 11576.5048 - acc: 0.0049
# Epoch 2/3
# 50000/50000 [==============================] - 22s 438us/step - loss: 11574.8386 - acc: 0.0045
# Epoch 3/3
# 50000/50000 [==============================] - 22s 432us/step - loss: 11574.0992 - acc: 0.0051

# %%
from keras.datasets import mnist
import numpy as np
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
print(np.prod(x_train.shape[1:]))
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

print(x_train.shape)
print(x_test.shape)
# Out:
# 784
# (60000, 784)
# (10000, 784)
